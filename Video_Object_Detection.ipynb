# %% [markdown]
# ## Video Upload to Amazon S3
#
# This section of the project focuses on uploading a video file to Amazon S3, preparing it for further analysis:
#
# 1. **AWS S3 Client Initialization**: Sets up a connection to Amazon S3 using boto3.
#
# 2. **Bucket Listing**: Retrieves and displays a list of available S3 buckets.
#
# 3. **Video Upload Process**:
#    - Specifies the local path of the video file.
#    - Uploads the video to a designated S3 bucket.
#    - Assigns a specific name to the uploaded file in S3.
#
# 4. **Error Handling**: Implements basic error catching to manage potential upload issues.
#
# This step is crucial for preparing video content for subsequent analysis using AWS Rekognition or other video processing services, enabling scalable and efficient video data management in the cloud.

# %%
import boto3

ACCESS_KEY = "AKIA4SDNV4MK62J2HEBI"
SECRET_KEY = "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"
BUCKET_NAME = "video2-analysis-bucket"

# Initialize S3 Client
s3 = boto3.client('s3', aws_access_key_id=ACCESS_KEY, aws_secret_access_key=SECRET_KEY)

# List Buckets
response = s3.list_buckets()
print("Buckets:", [bucket['Name'] for bucket in response['Buckets']])


try:
    file_path = "/Users/pawanbtw/Desktop/videoplayback.mp4"
    s3.upload_file(file_path, BUCKET_NAME, "football.mp4")  # Upload with .mp4 extension
    print(f"File uploaded to {BUCKET_NAME}")
except Exception as e:
    print("Error:", e)
# Out:
# Buckets: ['video2-analysis-bucket']
# File uploaded to video2-analysis-bucket

# %% [markdown]
# ## Video Analysis Initiation
#
# - Sets up Rekognition client
# - Starts asynchronous label detection on S3 video
# - Configures 50% confidence threshold
# - Retrieves job ID for tracking

# %%
# Rekognition Configuration
rekognition_client = boto3.client(
    'rekognition', 
    aws_access_key_id=ACCESS_KEY, 
    aws_secret_access_key=SECRET_KEY,
    region_name='us-east-1'  
)

# Start Rekognition Video Label Detection
response = rekognition_client.start_label_detection(
    Video={'S3Object': {'Bucket': BUCKET_NAME, 'Name': 'football.mp4'}},
    MinConfidence=50  # adjust confidence threshold as needed
)

# Extract Job ID from the response
job_id = response['JobId']
print(f"Started video analysis job with JobId: {job_id}")
# Out:
# Started video analysis job with JobId: 7efb95709a398aa4517d6331f256a1335b37ef20b79a960d85b5f4baba7f5bb7

# %% [markdown]
# ## Video Analysis Results Processing
#
# - Sets up Rekognition and DynamoDB clients
# - Creates DynamoDB table for results
# - Polls Rekognition for job completion
# - Retrieves and processes label detection results
# - Stores results in DynamoDB for further analysis

# %%
import boto3
import time

# AWS Configuration
ACCESS_KEY = "AKIA4SDNV4MK62J2HEBI"
SECRET_KEY = "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"
REGION = 'us-east-1'

rekognition_client = boto3.client(
    'rekognition',
    aws_access_key_id=ACCESS_KEY,
    aws_secret_access_key=SECRET_KEY,
    region_name=REGION
)

dynamodb_client = boto3.client(
    'dynamodb',
    aws_access_key_id=ACCESS_KEY,
    aws_secret_access_key=SECRET_KEY,
    region_name=REGION
)

# Step 1: Create DynamoDB Table
TABLE_NAME = 'RekognitionResults1'

def create_table():
    try:
        dynamodb_client.create_table(
            TableName=TABLE_NAME,
            KeySchema=[
                {'AttributeName': 'JobId', 'KeyType': 'HASH'},  # Partition key
                {'AttributeName': 'LabelName', 'KeyType': 'RANGE'},  # Sort key
            ],
            AttributeDefinitions=[
                {'AttributeName': 'JobId', 'AttributeType': 'S'},
                {'AttributeName': 'LabelName', 'AttributeType': 'S'},
            ],
            ProvisionedThroughput={
                'ReadCapacityUnits': 5,
                'WriteCapacityUnits': 5
            }
        )
        print(f"Creating table: {TABLE_NAME}.")
        dynamodb_client.get_waiter('table_exists').wait(TableName=TABLE_NAME)
        print("Table created and active!")
    except dynamodb_client.exceptions.ResourceInUseException:
        print(f"Table {TABLE_NAME} already exists.")

# Step 2: Store Rekognition Results in the Table
def store_results(job_id, labels):
    try:
        for label in labels:
            label_name = label['Label']['Name']
            confidence = label['Label']['Confidence']

            dynamodb_client.put_item(
                TableName=TABLE_NAME,
                Item={
                    'JobId': {'S': job_id},
                    'LabelName': {'S': label_name},
                    'Confidence': {'N': str(confidence)}
                }
            )
        print("Rekognition results stored successfully in DynamoDB!")
    except Exception as e:
        print(f"Error storing results: {e}")

# Step 3: Run Rekognition Label Detection and Store Results
def detect_labels_and_store(job_id):
    while True:
        try:
            response = rekognition_client.get_label_detection(JobId=job_id)
            status = response['JobStatus']
            if status in ['SUCCEEDED', 'FAILED']:
                break
            print('Job is still in progress...')
            time.sleep(5)
        except Exception as e:
            print(f"Error fetching job status: {e}")
            return

    if status == 'SUCCEEDED':
        print("Label detection job completed successfully!")
        labels = response.get('Labels', [])
        for label in labels:
            print(f"Label: {label['Label']['Name']}, Confidence: {label['Label']['Confidence']}")
        store_results(job_id, labels)
    else:
        print("Label detection job failed or was not found.")

# Main Execution
if __name__ == "__main__":
    job_id = '7efb95709a398aa4517d6331f256a1335b37ef20b79a960d85b5f4baba7f5bb7'  # Replace with your JobId
    create_table()
    detect_labels_and_store(job_id)
# Out:
# Creating table: RekognitionResults1.
# Table created and active!
# Label detection job completed successfully!
# Label: Adult, Confidence: 90.30839538574219
# Label: American Football, Confidence: 60.17186737060547
# Label: American Football (Ball), Confidence: 52.428977966308594
# Label: Arm, Confidence: 50.7934455871582
# Label: Astronomy, Confidence: 88.83755493164062
# Label: Ball, Confidence: 95.50232696533203
# Label: Body Part, Confidence: 51.604217529296875
# Label: Field, Confidence: 50.07183074951172
# Label: Football, Confidence: 95.50232696533203
# Label: Hand, Confidence: 51.25117111206055
# Label: Head, Confidence: 66.55892181396484
# Label: Kicking, Confidence: 55.832069396972656
# Label: Male, Confidence: 90.42467498779297
# Label: Man, Confidence: 90.30839538574219
# Label: Moon, Confidence: 88.83755493164062
# Label: Nature, Confidence: 88.83755493164062
# Label: Night, Confidence: 88.83755493164062
# Label: Outdoors, Confidence: 88.83755493164062
# Label: Person, Confidence: 90.42467498779297
# Label: Playing American Football, Confidence: 57.24143600463867
# Label: Playing Volleyball, Confidence: 56.34309768676758
# Label: Racket, Confidence: 52.26094436645508
# Label: Soccer, Confidence: 95.50232696533203
# Label: Soccer Ball, Confidence: 95.50232696533203
# Label: Sphere, Confidence: 53.564613342285156
# Label: Sport, Confidence: 95.50232696533203
# Label: Volleyball, Confidence: 56.65713119506836
# Label: Adult, Confidence: 89.97762298583984
# Label: American Football, Confidence: 50.62953186035156
# Label: Astronomy, Confidence: 73.95340728759766
# Label: Ball, Confidence: 67.4503402709961
# Label: Body Part, Confidence: 51.56824493408203
# Label: Boy, Confidence: 78.7711181640625
# Label: Child, Confidence: 78.7711181640625
# Label: Face, Confidence: 56.34865188598633
# Label: Female, Confidence: 61.00273132324219
# Label: Field, Confidence: 52.28144836425781
# Label: Football, Confidence: 67.4503402709961
# Label: Hand, Confidence: 51.528316497802734
# Label: Head, Confidence: 67.54309844970703
# Label: Kicking, Confidence: 50.280216217041016
# Label: Male, Confidence: 90.18802642822266
# Label: Man, Confidence: 89.97762298583984
# Label: Moon, Confidence: 72.14299011230469
# Label: Nature, Confidence: 74.159423828125
# Label: Night, Confidence: 74.02305603027344
# Label: Outdoors, Confidence: 74.159423828125
# Label: Person, Confidence: 90.18802642822266
# Label: Playing American Football, Confidence: 50.29811477661133
# Label: Soccer, Confidence: 67.4503402709961
# Label: Soccer Ball, Confidence: 67.4503402709961
# Label: Sport, Confidence: 67.4503402709961
# Label: Woman, Confidence: 61.00273132324219
# Label: Adult, Confidence: 88.62860107421875
# Label: American Football, Confidence: 50.41717529296875
# Label: Astronomy, Confidence: 64.83817291259766
# Label: Ball, Confidence: 96.1038818359375
# Label: Boy, Confidence: 80.07837677001953
# Label: Child, Confidence: 80.07837677001953
# Label: Face, Confidence: 52.32728958129883
# Label: Field, Confidence: 51.191471099853516
# Label: Football, Confidence: 96.1038818359375
# Label: Head, Confidence: 60.49946212768555
# Label: Kicking, Confidence: 51.63605880737305
# Label: Male, Confidence: 89.4920654296875
# Label: Man, Confidence: 87.88533020019531
# Label: Moon, Confidence: 61.381927490234375
# Label: Nature, Confidence: 65.23148345947266
# Label: Night, Confidence: 64.97115325927734
# Label: Outdoors, Confidence: 65.23148345947266
# Label: Person, Confidence: 90.23533630371094
# Label: Playing American Football, Confidence: 50.25899887084961
# Label: Soccer, Confidence: 96.1038818359375
# Label: Soccer Ball, Confidence: 96.1038818359375
# Label: Sport, Confidence: 96.1038818359375
# Label: Volleyball, Confidence: 50.989349365234375
# Label: Adult, Confidence: 86.3998794555664
# Label: American Football, Confidence: 54.74533462524414
# Label: Ball, Confidence: 98.05664825439453
# Label: Body Part, Confidence: 51.57042694091797
# Label: Field, Confidence: 50.41613006591797
# Label: Football, Confidence: 98.05664825439453
# Label: Hand, Confidence: 51.22464370727539
# Label: Head, Confidence: 66.91876983642578
# Label: Kicking, Confidence: 55.448150634765625
# Label: Male, Confidence: 85.68218231201172
# Label: Man, Confidence: 82.79769134521484
# Label: Nature, Confidence: 51.98839569091797
# Label: Outdoors, Confidence: 51.98839569091797
# Label: Person, Confidence: 87.1687240600586
# Label: Playing American Football, Confidence: 54.19186019897461
# Label: Playing Volleyball, Confidence: 51.913387298583984
# Label: Soccer, Confidence: 98.05664825439453
# Label: Soccer Ball, Confidence: 98.05664825439453
# Label: Sphere, Confidence: 52.771522521972656
# Label: Sport, Confidence: 98.05664825439453
# Label: Volleyball, Confidence: 54.40037536621094
# Label: Adult, Confidence: 71.92384338378906
# Label: American Football, Confidence: 57.379695892333984
# Label: Astronomy, Confidence: 83.67047119140625
# Label: Baby, Confidence: 55.138771057128906
# Label: Ball, Confidence: 99.99921417236328
# Label: Bride, Confidence: 52.626182556152344
# Label: Clothing, Confidence: 61.14927291870117
# Label: Female, Confidence: 62.179283142089844
# Label: Field, Confidence: 54.38300323486328
# Label: Football, Confidence: 99.99921417236328
# Label: Footwear, Confidence: 61.14927291870117
# Label: Head, Confidence: 63.165348052978516
# Label: Kicking, Confidence: 65.69868469238281
# Label: Male, Confidence: 61.2679443359375
# Label: Man, Confidence: 55.80022048950195
# Label: Moon, Confidence: 80.21422576904297
# Label: Nature, Confidence: 84.06378173828125
# Label: Night, Confidence: 83.8034439086914
# Label: Outdoors, Confidence: 84.06378173828125
# Label: Person, Confidence: 75.60763549804688
# Label: Playing American Football, Confidence: 56.27275085449219
# Label: Playing Volleyball, Confidence: 51.40651321411133
# Label: Shoe, Confidence: 61.14927291870117
# Label: Sneaker, Confidence: 61.14927291870117
# Label: Soccer, Confidence: 99.99921417236328
# Label: Soccer Ball, Confidence: 99.99921417236328
# Label: Sphere, Confidence: 55.655250549316406
# Label: Sport, Confidence: 99.99921417236328
# Label: Volleyball, Confidence: 69.49735260009766
# Label: Volleyball (Ball), Confidence: 55.668373107910156
# Label: Wedding, Confidence: 52.626182556152344
# Label: Woman, Confidence: 62.179283142089844
# Label: American Football, Confidence: 62.438232421875
# Label: Astronomy, Confidence: 81.7429428100586
# Label: Ball, Confidence: 100.0
# Label: Clothing, Confidence: 85.75696563720703
# Label: Field, Confidence: 54.87249755859375
# Label: Football, Confidence: 100.0
# Label: Footwear, Confidence: 85.75696563720703
# Label: Kicking, Confidence: 57.17182159423828
# Label: Male, Confidence: 52.46234893798828
# Label: Moon, Confidence: 80.01482391357422
# Label: Nature, Confidence: 81.9395980834961
# Label: Night, Confidence: 81.80943298339844
# Label: Outdoors, Confidence: 81.9395980834961
# Label: Person, Confidence: 61.26901626586914
# Label: Playing American Football, Confidence: 53.58268356323242
# Label: Playing Volleyball, Confidence: 50.50640106201172
# Label: Racket, Confidence: 50.099578857421875
# Label: Shoe, Confidence: 85.75696563720703
# Label: Sneaker, Confidence: 85.75696563720703
# Label: Soccer, Confidence: 100.0
# Label: Soccer Ball, Confidence: 100.0
# Label: Sphere, Confidence: 55.022403717041016
# Label: Sport, Confidence: 100.0
# Label: Volleyball, Confidence: 52.91865158081055
# Label: American Football, Confidence: 54.72486114501953
# Label: Astronomy, Confidence: 85.28394317626953
# Label: Ball, Confidence: 100.0
# Label: Field, Confidence: 53.281917572021484
# Label: Football, Confidence: 100.0
# Label: Kicking, Confidence: 54.5022087097168
# Label: Moon, Confidence: 85.28394317626953
# Label: Nature, Confidence: 85.28394317626953
# Label: Night, Confidence: 85.28394317626953
# Label: Outdoors, Confidence: 85.28394317626953
# Label: Person, Confidence: 55.84742736816406
# Label: Playing American Football, Confidence: 53.617916107177734
# Label: Rugby, Confidence: 87.37346649169922
# Label: Rugby Ball, Confidence: 87.37346649169922
# Label: Soccer, Confidence: 100.0
# Label: Soccer Ball, Confidence: 100.0
# Label: Sphere, Confidence: 54.673667907714844
# Label: Sport, Confidence: 100.0
# Label: American Football, Confidence: 54.312564849853516
# Label: Astronomy, Confidence: 82.2633285522461
# Label: Ball, Confidence: 100.0
# Label: Field, Confidence: 54.217838287353516
# Label: Football, Confidence: 100.0
# Label: Kicking, Confidence: 52.06938552856445
# Label: Moon, Confidence: 82.2633285522461
# Label: Nature, Confidence: 82.2633285522461
# Label: Night, Confidence: 82.2633285522461
# Label: Outdoors, Confidence: 82.2633285522461
# Label: Person, Confidence: 55.681678771972656
# Label: Playing American Football, Confidence: 53.759090423583984
# Label: Rugby, Confidence: 89.58409881591797
# Label: Rugby Ball, Confidence: 89.58409881591797
# Label: Soccer, Confidence: 100.0
# Label: Soccer Ball, Confidence: 100.0
# Label: Sphere, Confidence: 53.78404998779297
# Label: Sport, Confidence: 100.0
# Label: Adult, Confidence: 57.774452209472656
# Label: American Football, Confidence: 51.928321838378906
# Label: Astronomy, Confidence: 70.98355865478516
# Label: Ball, Confidence: 99.99995422363281
# Label: Basketball, Confidence: 72.43260192871094
# Label: Basketball (Ball), Confidence: 66.84088134765625
# Label: Field, Confidence: 51.94453811645508
# Label: Football, Confidence: 99.99995422363281
# Label: Kicking, Confidence: 52.30042266845703
# Label: Moon, Confidence: 70.98355865478516
# Label: Nature, Confidence: 71.37867736816406
# Label: Night, Confidence: 70.98355865478516
# Label: Outdoors, Confidence: 71.37867736816406
# Label: Person, Confidence: 66.12237548828125
# Label: Playing American Football, Confidence: 51.928321838378906
# Label: Rugby, Confidence: 55.783851623535156
# Label: Rugby Ball, Confidence: 55.783851623535156
# Label: Soccer, Confidence: 99.99995422363281
# Label: Soccer Ball, Confidence: 99.99995422363281
# Label: Sphere, Confidence: 53.27085876464844
# Label: Sport, Confidence: 99.99995422363281
# Label: Adult, Confidence: 63.18280792236328
# Label: American Football, Confidence: 69.42123413085938
# Label: Astronomy, Confidence: 64.31217956542969
# Label: Ball, Confidence: 99.86568450927734
# Label: Female, Confidence: 60.236534118652344
# Label: Field, Confidence: 56.57218933105469
# Label: Football, Confidence: 99.04098510742188
# Label: Head, Confidence: 57.62614822387695
# Label: Kicking, Confidence: 53.637630462646484
# Label: Moon, Confidence: 64.31217956542969
# Label: Nature, Confidence: 65.1024169921875
# Label: Night, Confidence: 64.31217956542969
# Label: Outdoors, Confidence: 65.1024169921875
# Label: Person, Confidence: 74.0064468383789
# Label: Playing American Football, Confidence: 69.42123413085938
# Label: Rugby, Confidence: 90.90122985839844
# Label: Rugby Ball, Confidence: 90.90122985839844
# Label: Sliding, Confidence: 57.433982849121094
# Label: Soccer, Confidence: 98.87310028076172
# Label: Soccer Ball, Confidence: 98.87310028076172
# Label: Sphere, Confidence: 50.61925506591797
# Label: Sport, Confidence: 99.86568450927734
# Label: Woman, Confidence: 60.236534118652344
# Label: Adult, Confidence: 88.26168060302734
# Label: American Football, Confidence: 70.38818359375
# Label: Ball, Confidence: 97.36100769042969
# Label: Female, Confidence: 86.78854370117188
# Label: Field, Confidence: 54.92782211303711
# Label: Football, Confidence: 96.95662689208984
# Label: Kicking, Confidence: 54.28056335449219
# Label: Person, Confidence: 90.03373718261719
# Label: Playing American Football, Confidence: 70.38818359375
# Label: Rugby, Confidence: 93.83496856689453
# Label: Rugby Ball, Confidence: 93.83496856689453
# Label: Sliding, Confidence: 83.2442398071289
# Label: Soccer, Confidence: 95.39949798583984
# Label: Soccer Ball, Confidence: 95.3758316040039
# Label: Sphere, Confidence: 51.06471252441406
# Label: Sport, Confidence: 98.60603332519531
# Label: Woman, Confidence: 86.78854370117188
# Label: Adult, Confidence: 92.98171997070312
# Label: American Football, Confidence: 77.06869506835938
# Label: Astronomy, Confidence: 57.04486083984375
# Label: Ball, Confidence: 91.73910522460938
# Label: Clothing, Confidence: 52.928558349609375
# Label: Fallen Person, Confidence: 50.567691802978516
# Label: Female, Confidence: 92.98171997070312
# Label: Field, Confidence: 58.508338928222656
# Label: Football, Confidence: 81.0339126586914
# Label: Footwear, Confidence: 52.928558349609375
# Label: Head, Confidence: 60.91823196411133
# Label: Kicking, Confidence: 53.60824966430664
# Label: Moon, Confidence: 57.04486083984375
# Label: Nature, Confidence: 60.05379104614258
# Label: Night, Confidence: 58.935054779052734
# Label: Outdoors, Confidence: 60.05379104614258
# Label: Person, Confidence: 94.9511489868164
# Label: Playing American Football, Confidence: 76.17267608642578
# Label: Rugby, Confidence: 89.97554016113281
# Label: Rugby Ball, Confidence: 89.97554016113281
# Label: Shoe, Confidence: 52.928558349609375
# Label: Sliding, Confidence: 87.72611236572266
# Label: Sneaker, Confidence: 51.933372497558594
# Label: Soccer, Confidence: 74.79900360107422
# Label: Soccer Ball, Confidence: 74.57770538330078
# Label: Sport, Confidence: 94.22915649414062
# Label: Woman, Confidence: 92.98171997070312
# Label: Adult, Confidence: 76.79899597167969
# Label: American Football, Confidence: 73.75826263427734
# Label: Ball, Confidence: 56.50339889526367
# Label: Clothing, Confidence: 60.89010238647461
# Label: Female, Confidence: 76.79899597167969
# Label: Field, Confidence: 69.7302474975586
# Label: Football, Confidence: 75.11418151855469
# Label: Footwear, Confidence: 60.89010238647461
# Label: Head, Confidence: 66.060791015625
# Label: Kicking, Confidence: 52.951175689697266
# Label: Nature, Confidence: 54.51234817504883
# Label: Night, Confidence: 53.14260482788086
# Label: Outdoors, Confidence: 54.51234817504883
# Label: Person, Confidence: 89.59104919433594
# Label: Playing American Football, Confidence: 71.96622467041016
# Label: Rain, Confidence: 50.74362564086914
# Label: Rugby, Confidence: 51.62225341796875
# Label: Rugby Ball, Confidence: 51.62225341796875
# Label: Shoe, Confidence: 60.89010238647461
# Label: Sliding, Confidence: 87.50772857666016
# Label: Sneaker, Confidence: 58.694602966308594
# Label: Soccer, Confidence: 52.598602294921875
# Label: Sport, Confidence: 76.76358795166016
# Label: Woman, Confidence: 76.79899597167969
# Label: Adult, Confidence: 60.674720764160156
# Label: American Football, Confidence: 68.20795440673828
# Label: American Football (Ball), Confidence: 50.746971130371094
# Label: Ball, Confidence: 65.54484558105469
# Label: Clothing, Confidence: 92.4386215209961
# Label: Female, Confidence: 58.63987731933594
# Label: Field, Confidence: 90.68233489990234
# Label: Football, Confidence: 68.20795440673828
# Label: Footwear, Confidence: 92.4386215209961
# Label: Nature, Confidence: 50.223323822021484
# Label: Outdoors, Confidence: 50.223323822021484
# Label: Person, Confidence: 65.79765319824219
# Label: Playing American Football, Confidence: 53.87169647216797
# Label: Rain, Confidence: 50.86394119262695
# Label: Shoe, Confidence: 92.4386215209961
# Label: Sliding, Confidence: 59.29405212402344
# Label: Sneaker, Confidence: 75.98657989501953
# Label: Sport, Confidence: 69.03266143798828
# Label: Woman, Confidence: 58.63987731933594
# Label: American Football, Confidence: 54.55953598022461
# Label: Boy, Confidence: 55.04168701171875
# Label: Child, Confidence: 55.04168701171875
# Label: Clothing, Confidence: 97.16654968261719
# Label: Field, Confidence: 95.06269073486328
# Label: Football, Confidence: 56.237335205078125
# Label: Footwear, Confidence: 97.16654968261719
# Label: Head, Confidence: 61.57844543457031
# Label: Male, Confidence: 55.04168701171875
# Label: Person, Confidence: 67.12008666992188
# Label: Playing American Football, Confidence: 52.268592834472656
# Label: Shoe, Confidence: 97.16654968261719
# Label: Sliding, Confidence: 54.42566680908203
# Label: Sneaker, Confidence: 89.68573760986328
# Label: Sport, Confidence: 56.237335205078125
# Label: American Football, Confidence: 54.207332611083984
# Label: Ball, Confidence: 53.912776947021484
# Label: Boy, Confidence: 57.937705993652344
# Label: Child, Confidence: 57.937705993652344
# Label: Clothing, Confidence: 94.95466613769531
# Label: Field, Confidence: 92.56278991699219
# Label: Football, Confidence: 59.68416213989258
# Label: Footwear, Confidence: 94.95466613769531
# Label: Head, Confidence: 64.6233901977539
# Label: Male, Confidence: 57.937705993652344
# Label: Person, Confidence: 67.88363647460938
# Label: Playing American Football, Confidence: 52.31349182128906
# Label: Shoe, Confidence: 94.95466613769531
# Label: Sliding, Confidence: 53.05342483520508
# Label: Sneaker, Confidence: 85.73040771484375
# Label: Soccer, Confidence: 50.27806091308594
# Label: Sport, Confidence: 59.68416213989258
# Label: American Football, Confidence: 60.15995407104492
# Label: Ball, Confidence: 92.4882583618164
# Label: Clothing, Confidence: 98.80166625976562
# Label: Field, Confidence: 55.581695556640625
# Label: Football, Confidence: 93.4645004272461
# Label: Footwear, Confidence: 98.80166625976562
# Label: Kicking, Confidence: 52.03841018676758
# Label: Person, Confidence: 56.95130920410156
# Label: Playing American Football, Confidence: 52.177337646484375
# Label: Shoe, Confidence: 98.80166625976562
# Label: Sliding, Confidence: 52.002620697021484
# Label: Sneaker, Confidence: 60.928314208984375
# Label: Soccer, Confidence: 92.10755157470703
# Label: Soccer Ball, Confidence: 86.36363983154297
# Label: Sport, Confidence: 93.4645004272461
# Label: American Football, Confidence: 54.2042121887207
# Label: Ball, Confidence: 97.52583312988281
# Label: Can, Confidence: 52.458011627197266
# Label: Clothing, Confidence: 98.56683349609375
# Label: Field, Confidence: 50.71907424926758
# Label: Football, Confidence: 97.84407806396484
# Label: Footwear, Confidence: 98.56683349609375
# Label: Kicking, Confidence: 53.17842483520508
# Label: Person, Confidence: 58.90555191040039
# Label: Playing American Football, Confidence: 53.206382751464844
# Label: Rugby, Confidence: 84.19860076904297
# Label: Rugby Ball, Confidence: 84.19860076904297
# Label: Shoe, Confidence: 98.56683349609375
# Label: Sliding, Confidence: 51.14773178100586
# Label: Sneaker, Confidence: 57.81155776977539
# Label: Soccer, Confidence: 97.3785629272461
# Label: Soccer Ball, Confidence: 95.45454406738281
# Label: Sport, Confidence: 97.84407806396484
# Label: Tin, Confidence: 52.458011627197266
# Label: Adult, Confidence: 74.42166137695312
# Label: American Football, Confidence: 53.589576721191406
# Label: Ball, Confidence: 100.0
# Label: Can, Confidence: 53.83236312866211
# Label: Clothing, Confidence: 97.47215270996094
# Label: Female, Confidence: 74.42166137695312
# Label: Football, Confidence: 100.0
# Label: Footwear, Confidence: 97.47215270996094
# Label: Kicking, Confidence: 53.0217170715332
# Label: Person, Confidence: 84.27386474609375
# Label: Playing American Football, Confidence: 52.32674026489258
# Label: Playing Volleyball, Confidence: 51.10664749145508
# Label: Rugby, Confidence: 86.73207092285156
# Label: Rugby Ball, Confidence: 86.73207092285156
# Label: Shoe, Confidence: 97.47215270996094
# Label: Sliding, Confidence: 50.514835357666016
# Label: Sneaker, Confidence: 57.366127014160156
# Label: Soccer, Confidence: 100.0
# Label: Soccer Ball, Confidence: 100.0
# Label: Sphere, Confidence: 50.81298065185547
# Label: Sport, Confidence: 100.0
# Label: Tin, Confidence: 53.83236312866211
# Label: Volleyball, Confidence: 51.109066009521484
# Label: Woman, Confidence: 74.42166137695312
# Label: Adult, Confidence: 64.5992431640625
# Label: American Football, Confidence: 59.405677795410156
# Label: Ball, Confidence: 100.0
# Label: Basketball, Confidence: 69.20316314697266
# Label: Basketball (Ball), Confidence: 63.646060943603516
# Label: Clothing, Confidence: 87.1100082397461
# Label: Female, Confidence: 64.5992431640625
# Label: Field, Confidence: 51.68891143798828
# Label: Football, Confidence: 100.0
# Label: Footwear, Confidence: 87.1100082397461
# Label: Head, Confidence: 66.16146850585938
# Label: Kicking, Confidence: 53.769657135009766
# Label: Person, Confidence: 74.61505126953125
# Label: Playing American Football, Confidence: 56.83187484741211
# Label: Rugby, Confidence: 55.59697723388672
# Label: Rugby Ball, Confidence: 55.59697723388672
# Label: Shoe, Confidence: 87.1100082397461
# Label: Sneaker, Confidence: 58.99911880493164
# Label: Soccer, Confidence: 100.0
# Label: Soccer Ball, Confidence: 100.0
# Label: Sphere, Confidence: 54.46828079223633
# Label: Sport, Confidence: 100.0
# Label: Woman, Confidence: 64.5992431640625
# Label: American Football, Confidence: 71.42514038085938
# Label: American Football (Ball), Confidence: 63.82589340209961
# Label: Ball, Confidence: 100.0
# Label: Clothing, Confidence: 98.09114074707031
# Label: Field, Confidence: 55.23712921142578
# Label: Football, Confidence: 100.0
# Label: Footwear, Confidence: 98.09114074707031
# Label: Grass, Confidence: 50.49317932128906
# Label: Kicking, Confidence: 51.521968841552734
# Label: Person, Confidence: 61.257389068603516
# Label: Plant, Confidence: 50.49317932128906
# Label: Playing American Football, Confidence: 56.21100616455078
# Label: Rugby, Confidence: 87.73900604248047
# Label: Rugby Ball, Confidence: 87.73900604248047
# Label: Running Shoe, Confidence: 50.23904800415039
# Label: Shoe, Confidence: 98.09114074707031
# Label: Sneaker, Confidence: 76.81803894042969
# Label: Soccer, Confidence: 100.0
# Label: Soccer Ball, Confidence: 100.0
# Label: Sphere, Confidence: 53.628963470458984
# Label: Sport, Confidence: 100.0
# Label: American Football, Confidence: 74.33538055419922
# Label: American Football (Ball), Confidence: 71.69982147216797
# Label: Ball, Confidence: 100.0
# Label: Clothing, Confidence: 98.28842163085938
# Label: Field, Confidence: 55.505435943603516
# Label: Football, Confidence: 100.0
# Label: Footwear, Confidence: 98.28842163085938
# Label: Grass, Confidence: 50.20218276977539
# Label: Kicking, Confidence: 51.50221633911133
# Label: Person, Confidence: 58.40016174316406
# Label: Plant, Confidence: 50.20218276977539
# Label: Playing American Football, Confidence: 53.435882568359375
# Label: Rain, Confidence: 52.332305908203125
# Label: Rugby, Confidence: 55.62955856323242
# Label: Rugby Ball, Confidence: 55.62955856323242
# Label: Shoe, Confidence: 98.28842163085938
# Label: Sneaker, Confidence: 59.85578155517578
# Label: Soccer, Confidence: 100.0
# Label: Soccer Ball, Confidence: 100.0
# Label: Sphere, Confidence: 53.63906478881836
# Label: Sport, Confidence: 100.0
# Label: American Football, Confidence: 72.41676330566406
# Label: American Football (Ball), Confidence: 72.41676330566406
# Label: Baby, Confidence: 68.01518249511719
# Label: Ball, Confidence: 100.0
# Label: Clothing, Confidence: 98.23064422607422
# Label: Field, Confidence: 56.4404411315918
# Label: Football, Confidence: 100.0
# Label: Footwear, Confidence: 98.23064422607422
# Label: Grass, Confidence: 51.32158660888672
# Label: Kicking, Confidence: 51.29576110839844
# Label: Person, Confidence: 77.7757568359375
# Label: Plant, Confidence: 51.32158660888672
# Label: Playing American Football, Confidence: 52.65586471557617
# Label: Rain, Confidence: 53.05209732055664
# Label: Rugby, Confidence: 90.88201904296875
# Label: Rugby Ball, Confidence: 90.88201904296875
# Label: Shoe, Confidence: 98.23064422607422
# Label: Sliding, Confidence: 50.02793884277344
# Label: Sneaker, Confidence: 57.956336975097656
# Label: Soccer, Confidence: 100.0
# Label: Soccer Ball, Confidence: 100.0
# Label: Sphere, Confidence: 53.59058380126953
# Label: Sport, Confidence: 100.0
# Label: American Football, Confidence: 71.09056091308594
# Label: American Football (Ball), Confidence: 71.09056091308594
# Label: Baby, Confidence: 69.62474060058594
# Label: Ball, Confidence: 100.0
# Label: Clothing, Confidence: 98.90502166748047
# Label: Field, Confidence: 56.458919525146484
# Label: Football, Confidence: 100.0
# Label: Footwear, Confidence: 98.90502166748047
# Label: Grass, Confidence: 50.35643005371094
# Label: Kicking, Confidence: 51.43852996826172
# Label: Person, Confidence: 76.75205993652344
# Label: Plant, Confidence: 50.35643005371094
# Label: Playing American Football, Confidence: 51.97690963745117
# Label: Rain, Confidence: 53.573509216308594
# Label: Rugby, Confidence: 88.40914154052734
# Label: Rugby Ball, Confidence: 88.40914154052734
# Label: Shoe, Confidence: 98.90502166748047
# Label: Sliding, Confidence: 50.19818115234375
# Label: Sneaker, Confidence: 56.80332946777344
# Label: Soccer, Confidence: 100.0
# Label: Soccer Ball, Confidence: 100.0
# Label: Sphere, Confidence: 53.54947280883789
# Label: Sport, Confidence: 100.0
# Label: American Football, Confidence: 71.32106018066406
# Label: American Football (Ball), Confidence: 71.32106018066406
# Label: Ball, Confidence: 100.0
# Label: Clothing, Confidence: 97.18560028076172
# Label: Field, Confidence: 55.8561897277832
# Label: Football, Confidence: 100.0
# Label: Footwear, Confidence: 97.18560028076172
# Label: Grass, Confidence: 50.57579040527344
# Label: Kicking, Confidence: 51.831451416015625
# Label: Person, Confidence: 59.220455169677734
# Label: Plant, Confidence: 50.57579040527344
# Label: Playing American Football, Confidence: 51.8064079284668
# Label: Rain, Confidence: 53.7297477722168
# Label: Rugby, Confidence: 51.18659591674805
# Label: Rugby Ball, Confidence: 51.18659591674805
# Label: Shoe, Confidence: 97.18560028076172
# Label: Sliding, Confidence: 50.08655548095703
# Label: Sneaker, Confidence: 56.43358612060547
# Label: Soccer, Confidence: 100.0
# Label: Soccer Ball, Confidence: 100.0
# Label: Sphere, Confidence: 54.24748992919922
# Label: Sport, Confidence: 100.0
# Label: American Football, Confidence: 75.35285949707031
# Label: American Football (Ball), Confidence: 72.94979095458984
# Label: Baby, Confidence: 67.82194519042969
# Label: Ball, Confidence: 100.0
# Label: Can, Confidence: 58.83877182006836
# Label: Clothing, Confidence: 98.17109680175781
# Label: Field, Confidence: 56.067176818847656
# Label: Football, Confidence: 100.0
# Label: Footwear, Confidence: 98.17109680175781
# Label: Kicking, Confidence: 51.62082290649414
# Label: Person, Confidence: 79.6928939819336
# Label: Playing American Football, Confidence: 51.48542022705078
# Label: Rain, Confidence: 54.15796661376953
# Label: Shoe, Confidence: 98.17109680175781
# Label: Sneaker, Confidence: 56.99566650390625
# Label: Soccer, Confidence: 100.0
# Label: Soccer Ball, Confidence: 100.0
# Label: Sphere, Confidence: 53.86418533325195
# Label: Sport, Confidence: 100.0
# Label: Tin, Confidence: 58.83877182006836
# Label: American Football, Confidence: 73.29288482666016
# Label: American Football (Ball), Confidence: 66.09754943847656
# Label: Ball, Confidence: 100.0
# Label: Can, Confidence: 60.0235595703125
# Label: Clothing, Confidence: 99.12307739257812
# Label: Field, Confidence: 56.21461868286133
# Label: Football, Confidence: 100.0
# Label: Footwear, Confidence: 99.12307739257812
# Label: Grass, Confidence: 50.24461364746094
# Label: Kicking, Confidence: 52.066280364990234
# Label: Person, Confidence: 56.77085494995117
# Label: Plant, Confidence: 50.24461364746094
# Label: Playing American Football, Confidence: 51.926963806152344
# Label: Rain, Confidence: 53.171844482421875
# Label: Running Shoe, Confidence: 50.09400177001953
# Label: Shoe, Confidence: 99.12307739257812
# Label: Sneaker, Confidence: 57.54800033569336
# Label: Soccer, Confidence: 100.0
# Label: Soccer Ball, Confidence: 100.0
# Label: Sphere, Confidence: 54.612640380859375
# Label: Sport, Confidence: 100.0
# Label: Tin, Confidence: 60.0235595703125
# Label: American Football, Confidence: 57.28756332397461
# Label: Ball, Confidence: 100.0
# Label: Can, Confidence: 69.33202362060547
# Label: Clothing, Confidence: 99.14378356933594
# Label: Field, Confidence: 56.53545379638672
# Label: Football, Confidence: 100.0
# Label: Footwear, Confidence: 99.14378356933594
# Label: Grass, Confidence: 50.41576385498047
# Label: Kicking, Confidence: 51.69859313964844
# Label: Person, Confidence: 56.940650939941406
# Label: Plant, Confidence: 50.41576385498047
# Label: Playing American Football, Confidence: 52.78715896606445
# Label: Rain, Confidence: 53.87135696411133
# Label: Rugby, Confidence: 72.1521224975586
# Label: Rugby Ball, Confidence: 72.1521224975586
# Label: Shoe, Confidence: 99.14378356933594
# Label: Sliding, Confidence: 50.251792907714844
# Label: Sneaker, Confidence: 57.512733459472656
# Label: Soccer, Confidence: 100.0
# Label: Soccer Ball, Confidence: 100.0
# Label: Sphere, Confidence: 53.683563232421875
# Label: Sport, Confidence: 100.0
# Label: Tin, Confidence: 69.33202362060547
# Label: American Football, Confidence: 56.18645095825195
# Label: Baby, Confidence: 60.50048065185547
# Label: Ball, Confidence: 100.0
# Label: Can, Confidence: 68.58174133300781
# Label: Clothing, Confidence: 99.2889404296875
# Label: Field, Confidence: 56.6781120300293
# Label: Football, Confidence: 100.0
# Label: Footwear, Confidence: 99.2889404296875
# Label: Grass, Confidence: 50.42988967895508
# Label: Kicking, Confidence: 51.83614730834961
# Label: Person, Confidence: 73.28949737548828
# Label: Plant, Confidence: 50.42988967895508
# Label: Playing American Football, Confidence: 52.81973648071289
# Label: Rain, Confidence: 53.10549545288086
# Label: Rugby, Confidence: 72.55769348144531
# Label: Rugby Ball, Confidence: 72.55769348144531
# Label: Shoe, Confidence: 99.2889404296875
# Label: Sneaker, Confidence: 57.632476806640625
# Label: Soccer, Confidence: 100.0
# Label: Soccer Ball, Confidence: 100.0
# Label: Sphere, Confidence: 53.71998596191406
# Label: Sport, Confidence: 100.0
# Label: Tin, Confidence: 68.58174133300781
# Label: American Football, Confidence: 74.16035461425781
# Label: American Football (Ball), Confidence: 65.84497833251953
# Label: Ball, Confidence: 100.0
# Label: Baseball, Confidence: 50.032127380371094
# Label: Can, Confidence: 69.00841522216797
# Label: Clothing, Confidence: 99.51403045654297
# Label: Field, Confidence: 57.57831954956055
# Label: Football, Confidence: 100.0
# Label: Footwear, Confidence: 99.51403045654297
# Label: Grass, Confidence: 51.82691192626953
# Label: Kicking, Confidence: 51.597412109375
# Label: Person, Confidence: 57.72025680541992
# Label: Plant, Confidence: 51.82691192626953
# Label: Playing American Football, Confidence: 54.89451217651367
# Label: Playing Baseball, Confidence: 50.032127380371094
# Label: Rain, Confidence: 53.281131744384766
# Label: Running Shoe, Confidence: 50.16493606567383
# Label: Shoe, Confidence: 99.51403045654297
# Label: Sneaker, Confidence: 57.87721252441406
# Label: Soccer, Confidence: 100.0
# Label: Soccer Ball, Confidence: 100.0
# Label: Sphere, Confidence: 53.888736724853516
# Label: Sport, Confidence: 100.0
# Label: Tin, Confidence: 69.00841522216797
# Rekognition results stored successfully in DynamoDB!

# %%
# AWS Configuration
ACCESS_KEY = "AKIA4SDNV4MK62J2HEBI"
SECRET_KEY = "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"
REGION = 'us-east-1'
BUCKET_NAME = "video2-analysis-bucket"
TABLE_NAME = 'RekognitionResults1'

# CloudWatch Configuration
log_group = 'ImageProcessingLogs'
log_stream = 'ImageProcessingStream'

# Initialize AWS Clients
s3 = boto3.client('s3', aws_access_key_id=ACCESS_KEY, aws_secret_access_key=SECRET_KEY)
rekognition_client = boto3.client('rekognition', aws_access_key_id=ACCESS_KEY, aws_secret_access_key=SECRET_KEY, region_name=REGION)
dynamodb_client = boto3.client('dynamodb', aws_access_key_id=ACCESS_KEY, aws_secret_access_key=SECRET_KEY, region_name=REGION)
logs_client = boto3.client('logs', aws_access_key_id=ACCESS_KEY, aws_secret_access_key=SECRET_KEY, region_name=REGION)

# CloudWatch Logging Functions
def create_log_group_and_stream():
    try:
        logs_client.create_log_group(logGroupName=log_group)
    except logs_client.exceptions.ResourceAlreadyExistsException:
        pass

    try:
        logs_client.create_log_stream(logGroupName=log_group, logStreamName=log_stream)
    except logs_client.exceptions.ResourceAlreadyExistsException:
        pass

def log_to_cloudwatch(message):
    timestamp = int(round(time.time() * 1000))
    logs_client.put_log_events(
        logGroupName=log_group,
        logStreamName=log_stream,
        logEvents=[{
            'timestamp': timestamp,
            'message': message
        }]
    )

# Step 1: Upload Video to S3
def upload_video_to_s3(file_path):
    try:
        log_to_cloudwatch("Uploading video to S3...")
        s3.upload_file(file_path, BUCKET_NAME, "Pawan_Karthik_Elevator_Pitch.mp4")
        log_to_cloudwatch(f"Video uploaded to S3 bucket: {BUCKET_NAME}")
    except Exception as e:
        log_to_cloudwatch(f"Error uploading video to S3: {e}")
        raise

# Step 2: Start Rekognition Video Label Detection
def start_label_detection():
    try:
        log_to_cloudwatch("Starting Rekognition label detection...")
        response = rekognition_client.start_label_detection(
            Video={'S3Object': {'Bucket': BUCKET_NAME, 'Name': 'Pawan_Karthik_Elevator_Pitch.mp4'}},
            MinConfidence=50
        )
        job_id = response['JobId']
        log_to_cloudwatch(f"Started Rekognition job with JobId: {job_id}")
        return job_id
    except Exception as e:
        log_to_cloudwatch(f"Error starting label detection: {e}")
        raise

# Step 3: Create DynamoDB Table
def create_table():
    try:
        log_to_cloudwatch("Creating DynamoDB table...")
        dynamodb_client.create_table(
            TableName=TABLE_NAME,
            KeySchema=[
                {'AttributeName': 'JobId', 'KeyType': 'HASH'},
                {'AttributeName': 'LabelName', 'KeyType': 'RANGE'},
            ],
            AttributeDefinitions=[
                {'AttributeName': 'JobId', 'AttributeType': 'S'},
                {'AttributeName': 'LabelName', 'AttributeType': 'S'},
            ],
            ProvisionedThroughput={
                'ReadCapacityUnits': 5,
                'WriteCapacityUnits': 5
            }
        )
        dynamodb_client.get_waiter('table_exists').wait(TableName=TABLE_NAME)
        log_to_cloudwatch("DynamoDB table created successfully!")
    except dynamodb_client.exceptions.ResourceInUseException:
        log_to_cloudwatch(f"DynamoDB table {TABLE_NAME} already exists.")
    except Exception as e:
        log_to_cloudwatch(f"Error creating DynamoDB table: {e}")
        raise

# Step 4: Store Rekognition Results in DynamoDB
def store_results(job_id, labels):
    try:
        log_to_cloudwatch("Storing Rekognition results in DynamoDB...")
        for label in labels:
            label_name = label['Label']['Name']
            confidence = label['Label']['Confidence']

            dynamodb_client.put_item(
                TableName=TABLE_NAME,
                Item={
                    'JobId': {'S': job_id},
                    'LabelName': {'S': label_name},
                    'Confidence': {'N': str(confidence)}
                }
            )
        log_to_cloudwatch("Rekognition results stored successfully in DynamoDB!")
    except Exception as e:
        log_to_cloudwatch(f"Error storing results in DynamoDB: {e}")
        raise

# Step 5: Detect Labels and Store Results
def detect_labels_and_store(job_id):
    while True:
        try:
            response = rekognition_client.get_label_detection(JobId=job_id)
            status = response['JobStatus']
            if status in ['SUCCEEDED', 'FAILED']:
                break
            log_to_cloudwatch("Rekognition job is still in progress...")
            time.sleep(5)
        except Exception as e:
            log_to_cloudwatch(f"Error fetching job status: {e}")
            return

    if status == 'SUCCEEDED':
        log_to_cloudwatch("Rekognition label detection completed successfully!")
        labels = response.get('Labels', [])
        for label in labels:
            log_to_cloudwatch(f"Detected Label: {label['Label']['Name']}, Confidence: {label['Label']['Confidence']}")
        store_results(job_id, labels)
    else:
        log_to_cloudwatch("Rekognition job failed or was not found.")

# Main Execution
if __name__ == "__main__":
    create_log_group_and_stream()
    file_path = "/Users/pawanbtw/Desktop/videoplayback.mp4"
    
    upload_video_to_s3(file_path)
    
    create_table()
    
    job_id = start_label_detection()
    
    detect_labels_and_store(job_id)

# %%
import cv2
import numpy as np
from PIL import Image
import io

# AWS Configuration
ACCESS_KEY = "AKIA4SDNV4MK62J2HEBI"
SECRET_KEY = "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"
REGION = 'us-east-1'
BUCKET_NAME = "video2-analysis-bucket"
TABLE_NAME = 'RekognitionResults1'

# CloudWatch Configuration
log_group = 'ImageProcessingLogs'
log_stream = 'ImageProcessingStream'

# Initialize AWS Clients
s3 = boto3.client('s3', aws_access_key_id=ACCESS_KEY, aws_secret_access_key=SECRET_KEY)
rekognition_client = boto3.client('rekognition', aws_access_key_id=ACCESS_KEY, aws_secret_access_key=SECRET_KEY, region_name=REGION)
dynamodb_client = boto3.client('dynamodb', aws_access_key_id=ACCESS_KEY, aws_secret_access_key=SECRET_KEY, region_name=REGION)
logs_client = boto3.client('logs', aws_access_key_id=ACCESS_KEY, aws_secret_access_key=SECRET_KEY, region_name=REGION)

# CloudWatch Logging Functions
def create_log_group_and_stream():
    try:
        logs_client.create_log_group(logGroupName=log_group)
    except logs_client.exceptions.ResourceAlreadyExistsException:
        pass

    try:
        logs_client.create_log_stream(logGroupName=log_group, logStreamName=log_stream)
    except logs_client.exceptions.ResourceAlreadyExistsException:
        pass

def log_to_cloudwatch(message):
    timestamp = int(round(time.time() * 1000))
    logs_client.put_log_events(
        logGroupName=log_group,
        logStreamName=log_stream,
        logEvents=[{
            'timestamp': timestamp,
            'message': message
        }]
    )

# Step 1: Upload Video to S3
def upload_video_to_s3(file_path):
    try:
        log_to_cloudwatch("Uploading video to S3...")
        s3.upload_file(file_path, BUCKET_NAME, "Pawan_Karthik_Elevator_Pitch.mp4")
        log_to_cloudwatch(f"Video uploaded to S3 bucket: {BUCKET_NAME}")
    except Exception as e:
        log_to_cloudwatch(f"Error uploading video to S3: {e}")
        raise

# Step 2: Start Rekognition Video Label Detection
def start_label_detection():
    try:
        log_to_cloudwatch("Starting Rekognition label detection...")
        response = rekognition_client.start_label_detection(
            Video={'S3Object': {'Bucket': BUCKET_NAME, 'Name': 'Pawan_Karthik_Elevator_Pitch.mp4'}},
            MinConfidence=50
        )
        job_id = response['JobId']
        log_to_cloudwatch(f"Started Rekognition job with JobId: {job_id}")
        return job_id
    except Exception as e:
        log_to_cloudwatch(f"Error starting label detection: {e}")
        raise

# Step 3: Create DynamoDB Table
def create_table():
    try:
        log_to_cloudwatch("Creating DynamoDB table...")
        dynamodb_client.create_table(
            TableName=TABLE_NAME,
            KeySchema=[
                {'AttributeName': 'JobId', 'KeyType': 'HASH'},
                {'AttributeName': 'LabelName', 'KeyType': 'RANGE'},
            ],
            AttributeDefinitions=[
                {'AttributeName': 'JobId', 'AttributeType': 'S'},
                {'AttributeName': 'LabelName', 'AttributeType': 'S'},
            ],
            ProvisionedThroughput={
                'ReadCapacityUnits': 5,
                'WriteCapacityUnits': 5
            }
        )
        dynamodb_client.get_waiter('table_exists').wait(TableName=TABLE_NAME)
        log_to_cloudwatch("DynamoDB table created successfully!")
    except dynamodb_client.exceptions.ResourceInUseException:
        log_to_cloudwatch(f"DynamoDB table {TABLE_NAME} already exists.")
    except Exception as e:
        log_to_cloudwatch(f"Error creating DynamoDB table: {e}")
        raise

# Step 4: Store Rekognition Results in DynamoDB
def store_results(job_id, labels):
    try:
        log_to_cloudwatch("Storing Rekognition results in DynamoDB...")
        for label in labels:
            label_name = label['Label']['Name']
            confidence = label['Label']['Confidence']

            dynamodb_client.put_item(
                TableName=TABLE_NAME,
                Item={
                    'JobId': {'S': job_id},
                    'LabelName': {'S': label_name},
                    'Confidence': {'N': str(confidence)}
                }
            )
        log_to_cloudwatch("Rekognition results stored successfully in DynamoDB!")
    except Exception as e:
        log_to_cloudwatch(f"Error storing results in DynamoDB: {e}")
        raise

# Step 5: Detect Labels and Store Results
def detect_labels_and_store(job_id):
    while True:
        try:
            response = rekognition_client.get_label_detection(JobId=job_id)
            status = response['JobStatus']
            if status in ['SUCCEEDED', 'FAILED']:
                break
            log_to_cloudwatch("Rekognition job is still in progress...")
            time.sleep(5)
        except Exception as e:
            log_to_cloudwatch(f"Error fetching job status: {e}")
            return

    if status == 'SUCCEEDED':
        log_to_cloudwatch("Rekognition label detection completed successfully!")
        labels = response.get('Labels', [])
        for label in labels:
            log_to_cloudwatch(f"Detected Label: {label['Label']['Name']}, Confidence: {label['Label']['Confidence']}")
        store_results(job_id, labels)
    else:
        log_to_cloudwatch("Rekognition job failed or was not found.")

# New function to process frames and store in S3
def process_and_store_frames(job_id):
    log_to_cloudwatch("Processing frames and storing in S3...")
    
    # Get video metadata
    response = s3.head_object(Bucket=BUCKET_NAME, Key="Pawan_Karthik_Elevator_Pitch.mp4")
    content_length = int(response['ContentLength'])
    
    # Download video from S3
    s3.download_file(BUCKET_NAME, "Pawan_Karthik_Elevator_Pitch.mp4", "temp_video.mp4")
    
    # Open video file
    cap = cv2.VideoCapture("temp_video.mp4")
    
    frame_count = 0
    while True:
        ret, frame = cap.read()
        if not ret:
            break
        
        # Get labels for this frame
        response = rekognition_client.get_label_detection(JobId=job_id, MaxResults=10, NextToken='')
        labels = response.get('Labels', [])
        
        # Draw bounding boxes
        for label in labels:
            if 'Instances' in label['Label']:
                for instance in label['Label']['Instances']:
                    bbox = instance['BoundingBox']
                    left = int(bbox['Left'] * frame.shape[1])
                    top = int(bbox['Top'] * frame.shape[0])
                    width = int(bbox['Width'] * frame.shape[1])
                    height = int(bbox['Height'] * frame.shape[0])
                    
                    cv2.rectangle(frame, (left, top), (left + width, top + height), (0, 255, 0), 2)
                    cv2.putText(frame, label['Label']['Name'], (left, top - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (36,255,12), 2)
        
        # Convert frame to PNG
        success, buffer = cv2.imencode(".png", frame)
        io_buf = io.BytesIO(buffer)
        
        # Upload to S3
        s3.upload_fileobj(io_buf, BUCKET_NAME, f"processed_frames/frame_{frame_count}.png")
        
        frame_count += 1
    
    cap.release()
    log_to_cloudwatch(f"Processed and stored {frame_count} frames in S3.")

# Main Execution
if __name__ == "__main__":
    create_log_group_and_stream()
    file_path = "/Users/pawanbtw/Desktop/videoplayback.mp4"
    
    upload_video_to_s3(file_path)
    
    create_table()
    
    job_id = start_label_detection()
    
    detect_labels_and_store(job_id)
    
    # Process and store frames
    process_and_store_frames(job_id)
